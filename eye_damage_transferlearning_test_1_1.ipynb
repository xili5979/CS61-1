# %% [markdown]
# <a href="https://colab.research.google.com/github/xili5979/CS61-1/blob/main/eye_damage_transferlearning_test_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Eye Damage Detection Model Test

# %% [markdown]
# ## Enabling and testing the TPU

# %%
# %tensorflow_version 2.x
# import tensorflow as tf
# print("Tensorflow version " + tf.__version__)

# try:
#   tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection
#   print('Running on TPU ', tpu.cluster_spec().as_dict()['worker'])
# except ValueError:
#   raise BaseException('ERROR: Not connected to a TPU runtime; please see the previous cell in this notebook for instructions!')

# tf.config.experimental_connect_to_cluster(tpu)
# tf.tpu.experimental.initialize_tpu_system(tpu)
# tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)

# %% [markdown]
# ## GPU

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Tue Oct  5 05:45:14 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    32W / 250W |    345MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## import

# %%
import re
import os, glob, cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import get_custom_objects
from tqdm import tqdm

# %% [markdown]
# ## Set configurations and read metadata

# %%
#unzip file
# !unzip "/content/drive/MyDrive/5703File/DataSet/ODIR-5K.zip" -d "/content"
# !unzip "/content/drive/MyDrive/5703File/DataSet/cataract.zip" -d "/content"
# !unrar x -r "/content/drive/MyDrive/DDR_dataset/*.rar" "/content"
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: /content/ODIR-5K/Training Images/1327_right.jpg
#   inflating: /content/ODIR-5K/Training Images/2917_left.jpg
#   inflating: /content/ODIR-5K/Training Images/2587_left.jpg
#   inflating: /content/ODIR-5K/Training Images/834_left.jpg
#   inflating: /content/ODIR-5K/Training Images/2112_right.jpg
#   inflating: /content/ODIR-5K/Training Images/2916_left.jpg
#   inflating: /content/ODIR-5K/Training Images/2438_right.jpg
#   inflating: /content/ODIR-5K/Training Images/2586_left.jpg
#   inflating: /content/ODIR-5K/Training Images/835_left.jpg
#   inflating: /content/ODIR-5K/Training Images/90_right.jpg
#   inflating: /content/ODIR-5K/Training Images/59_right.jpg
#   inflating: /content/ODIR-5K/Training Images/2923_right.jpg
#   inflating: /content/ODIR-5K/Training Images/2149_left.jpg
#   inflating: /content/ODIR-5K/Training Images/4240_left.jpg
#   inflating: /content/ODIR-5K/Training Images/3381_left.jpg
#   inflating: /content/ODIR-5K/Training Images/4026_left.jpg
#   inflating: /content/ODIR-5K/Training Images/2262_right.jpg
#   inflating: /content/ODIR-5K/Training Images/2781_right.jpg
#   inflating: /content/ODIR-5K/Training Images/2748_right.jpg
#   inflating: /content/ODIR-5K/Training Images/1286_left.jpg
#   inflating: /content/ODIR-5K/Training Images/2865_right.jpg
#   inflating: /content/ODIR-5K/Training Images/4027_left.jpg
#   inflating: /content/ODIR-5K/Training Images/1287_left.jpg
#   inflating: /content/ODIR-5K/Training Images/4241_left.jpg
#   inflating: /content/ODIR-5K/Training Images/3380_left.jpg
#   inflating: /content/ODIR-5K/Training Images/3085_left.jpg
#   inflating: /content/ODIR-5K/Training Images/4421_right.jpg
#   inflating: /content/ODIR-5K/Training Images/4144_left.jpg
#   inflating: /content/ODIR-5K/Training Images/4322_left.jpg
#   inflating: /content/ODIR-5K/Training Images/3037_right.jpg
#   inflating: /content/ODIR-5K/Training Images/1032_right.jpg
#   inflating: /content/ODIR-5K/Training Images/108_left.jpg
#   inflating: /content/ODIR-5K/Training Images/55_left.jpg
#   inflating: /content/ODIR-5K/Training Images/631_right.jpg
#   inflating: /content/ODIR-5K/Training Images/4323_left.jpg
#   inflating: /content/ODIR-5K/Training Images/3201_right.jpg
#   inflating: /content/ODIR-5K/Training Images/4617_right.jpg
#   inflating: /content/ODIR-5K/Training Images/3084_left.jpg
#   inflating: /content/ODIR-5K/Training Images/407_right.jpg
#   inflating: /content/ODIR-5K/Training Images/109_left.jpg
#   inflating: /content/ODIR-5K/Training Images/54_left.jpg
#   inflating: /content/ODIR-5K/Training Images/777_right.jpg
#   inflating: /content/ODIR-5K/Training Images/3940_right.jpg
#   inflating: /content/ODIR-5K/Training Images/294_right.jpg
#   inflating: /content/ODIR-5K/Training Images/1174_right.jpg
#   inflating: /content/ODIR-5K/Training Images/1497_right.jpg
#   inflating: /content/ODIR-5K/Training Images/2683_left.jpg
#   inflating: /content/ODIR-5K/Training Images/3171_right.jpg
#   inflating: /content/ODIR-5K/Training Images/4084_right.jpg
#   inflating: /content/ODIR-5K/Training Images/956_left.jpg
#   inflating: /content/ODIR-5K/Training Images/4567_right.jpg
#   inflating: /content/ODIR-5K/Training Images/2875_left.jpg
#   inflating: /content/ODIR-5K/Training Images/588_right.jpg
#   inflating: /content/ODIR-5K/Training Images/541_right.jpg
#   inflating: /content/ODIR-5K/Training Images/957_left.jpg
#   inflating: /content/ODIR-5K/Training Images/2874_left.jpg
#   inflating: /content/ODIR-5K/Training Images/893_right.jpg
#   inflating: /content/ODIR-5K/Training Images/3347_right.jpg
#   inflating: /content/ODIR-5K/Training Images/2682_left.jpg
#   inflating: /content/ODIR-5K/Training Images/3379_left.jpg
#   inflating: /content/ODIR-5K/Training Images/1018_left.jpg
#   inflating: /content/ODIR-5K/Training Images/2388_right.jpg
#   inflating: /content/ODIR-5K/Training Images/2341_right.jpg
#   inflating: /content/ODIR-5K/Training Images/3378_left.jpg
#   inflating: /content/ODIR-5K/Training Images/1019_left.jpg
#   inflating: /content/ODIR-5K/Training Images/2946_right.jpg
#   inflating: /content/ODIR-5K/Training Images/2177_right.jpg
#   inflating: /content/ODIR-5K/Training Images/2494_right.jpg
#   inflating: /content/ODIR-5K/Training Images/2207_right.jpg
#   inflating: /content/ODIR-5K/Training Images/4676_left.jpg
#   inflating: /content/ODIR-5K/Training Images/1846_left.jpg
#   inflating: /content/ODIR-5K/Training Images/3941_left.jpg
#   inflating: /content/ODIR-5K/Training Images/4410_left.jpg
#   inflating: /content/ODIR-5K/Training Images/2719_left.jpg
#   inflating: /content/ODIR-5K/Training Images/3940_left.jpg
#   inflating: /content/ODIR-5K/Training Images/4411_left.jpg
#   inflating: /content/ODIR-5K/Training Images/1847_left.jpg
#   inflating: /content/ODIR-5K/Training Images/4677_left.jpg
#   inflating: /content/ODIR-5K/Training Images/2800_right.jpg
#   inflating: /content/ODIR-5K/Training Images/2718_left.jpg
#   inflating: /content/ODIR-5K/Training Images/227_right.jpg
#   inflating: /content/ODIR-5K/Training Images/1424_right.jpg
#   inflating: /content/ODIR-5K/Training Images/3421_right.jpg
#   inflating: /content/ODIR-5K/Training Images/2123_left.jpg
#   inflating: /content/ODIR-5K/Training Images/2345_left.jpg
#   inflating: /content/ODIR-5K/Training Images/266_left.jpg
#   inflating: /content/ODIR-5K/Training Images/4037_right.jpg
#   inflating: /content/ODIR-5K/Training Images/1612_right.jpg
#   inflating: /content/ODIR-5K/Training Images/2344_left.jpg
#   inflating: /content/ODIR-5K/Training Images/4201_right.jpg
#   inflating: /content/ODIR-5K/Training Images/267_left.jpg
#   inflating: /content/ODIR-5K/Training Images/2122_left.jpg
#   inflating: /content/ODIR-5K/Training Images/820_right.jpg
#   inflating: /content/ODIR-5K/Training Images/1879_right.jpg
#   inflating: /content/ODIR-5K/Training Images/4492_right.jpg
#   inflating: /content/ODIR-5K/Training Images/1444_left.jpg
#   inflating: /content/ODIR-5K/Training Images/4171_right.jpg
#   inflating: /content/ODIR-5K/Training Images/3084_right.jpg
#   inflating: /content/ODIR-5K/Training Images/1562_right.jpg
#   inflating: /content/ODIR-5K/Training Images/1081_right.jpg
#   inflating: /content/ODIR-5K/Training Images/
#   inflating: /content/dataset/3_retina_disease/Retina_081.png
#   inflating: /content/dataset/3_retina_disease/Retina_082.png
#   inflating: /content/dataset/3_retina_disease/Retina_083.png
#   inflating: /content/dataset/3_retina_disease/Retina_084.png
#   inflating: /content/dataset/3_retina_disease/Retina_085.png
#   inflating: /content/dataset/3_retina_disease/Retina_086.png
#   inflating: /content/dataset/3_retina_disease/Retina_087.png
#   inflating: /content/dataset/3_retina_disease/Retina_088.png
#   inflating: /content/dataset/3_retina_disease/Retina_089.png
#   inflating: /content/dataset/3_retina_disease/Retina_090.png
#   inflating: /content/dataset/3_retina_disease/Retina_091.png
#   inflating: /content/dataset/3_retina_disease/Retina_092.png
#   inflating: /content/dataset/3_retina_disease/Retina_093.png
#   inflating: /content/dataset/3_retina_disease/Retina_094.png
#   inflating: /content/dataset/3_retina_disease/Retina_095.png
#   inflating: /content/dataset/3_retina_disease/Retina_096.png
#   inflating: /content/dataset/3_retina_disease/Retina_097.png
#   inflating: /content/dataset/3_retina_disease/Retina_098.png
#   inflating: /content/dataset/3_retina_disease/Retina_099.png
#   inflating: /content/dataset/3_retina_disease/Retina_100.png
#   inflating: /content/dataset/3_retina_disease/._Retina_005.png
#
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
# No files to extract

# %%
# !unzip "/content/drive/MyDrive/5703File/DataSet/DDR_dataset/DDR-dataset.zip.001.zip" -d "/content"

# %%
# cataract dataset
IMG_ROOT = '/content/dataset/'
IMG_DIR = [IMG_ROOT+'1_normal', 
           IMG_ROOT+'2_cataract', 
           IMG_ROOT+'2_glaucoma', 
           IMG_ROOT+'3_retina_disease']

# ocular-disease-recognition dataset
OCU_IMG_ROOT = '/content/ODIR-5K/Training Images/'
ocu_df = pd.read_csv('/content/ODIR-5K/full_df.csv')

# %%
# restore the data

# %% [markdown]
# ### use PyDrive

# %%
SEED = 42
def seed_everything(seed):
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)

seed_everything(SEED)

# %% [markdown]
# ## Process Cataract dataset

# %%
cat_df = pd.DataFrame(0, 
                  columns=['paths', 
                           'disease'],
                  index=range(601))

filepaths = glob.glob(IMG_ROOT + '*/*')


for i, filepath in enumerate(filepaths):
    filepath = os.path.split(filepath)
    cat_df.iloc[i, 0] = filepath[0] + '/' + filepath[1]
    
    if filepath[0] == IMG_DIR[0]:    # normal
        cat_df.iloc[i, 1] = 0
    elif filepath[0] == IMG_DIR[1]:  # cataract
        cat_df.iloc[i, 1] = 1
    elif filepath[0] == IMG_DIR[2]:  # glaucoma
        cat_df.iloc[i, 1] = 2
    elif filepath[0] == IMG_DIR[3]:  # retine_disease
        cat_df.iloc[i, 1] = 3
        
# only sample normal and cataract and other disease      
cat_df = cat_df.query('0 <= disease < 2 or disease == 3')
# cat_df = cat_df.query('disease == 3')
cat_df

# can
# Out:
#                                             paths  disease
# 0    /content/dataset/2_cataract/cataract_027.png        1
# 1    /content/dataset/2_cataract/cataract_053.png        1
# 2    /content/dataset/2_cataract/cataract_023.png        1
# 3    /content/dataset/2_cataract/cataract_030.png        1
# 4    /content/dataset/2_cataract/cataract_098.png        1
# ..                                            ...      ...
# 596          /content/dataset/1_normal/NL_245.png        0
# 597          /content/dataset/1_normal/NL_084.png        0
# 598          /content/dataset/1_normal/NL_058.png        0
# 599          /content/dataset/1_normal/NL_183.png        0
# 600          /content/dataset/1_normal/NL_059.png        0
#
# [500 rows x 2 columns]

# %%
print('Number of normal(0) and cataract(1) and other_disease(3) images')
print(cat_df['disease'].value_counts())
# Out:
# Number of normal(0) and cataract(1) and other_disease(3) images
# 0    300
# 3    100
# 1    100
# Name: disease, dtype: int64

# %% [markdown]
# ## Process Ocular Disease Dataset

# %%
ocu_df.head()
# I only need filename and lables
# N-normal-0, C-cataract-1, A-AMD-4, D,G,H,M,O-Others-3
# Out:
#    ID  Patient Age Patient Sex  ... labels                    target     filename
# 0   0           69      Female  ...  ['N']  [1, 0, 0, 0, 0, 0, 0, 0]  0_right.jpg
# 1   1           57        Male  ...  ['N']  [1, 0, 0, 0, 0, 0, 0, 0]  1_right.jpg
# 2   2           42        Male  ...  ['D']  [0, 1, 0, 0, 0, 0, 0, 0]  2_right.jpg
# 3   4           53        Male  ...  ['D']  [0, 1, 0, 0, 0, 0, 0, 0]  4_right.jpg
# 4   5           50      Female  ...  ['D']  [0, 1, 0, 0, 0, 0, 0, 0]  5_right.jpg
#
# [5 rows x 19 columns]

# %%
ocu_df.shape
# Out:
# (6392, 19)

# %%
new_ocu_df = ocu_df.loc[:,['filename','labels']]
new_ocu_df.columns = ['paths','disease']

# %%
new_ocu_df
# Out:
#               paths disease
# 0       0_right.jpg   ['N']
# 1       1_right.jpg   ['N']
# 2       2_right.jpg   ['D']
# 3       4_right.jpg   ['D']
# 4       5_right.jpg   ['D']
# ...             ...     ...
# 6387  4686_left.jpg   ['D']
# 6388  4688_left.jpg   ['D']
# 6389  4689_left.jpg   ['D']
# 6390  4690_left.jpg   ['D']
# 6391  4784_left.jpg   ['H']
#
# [6392 rows x 2 columns]

# %%
def change_label(text):
    if 'N' in text:
        return 0
    if 'C' in text:
        return 1
    if 'A' in text:
        return 2
    if 'D' in text:
        return 7
    if 'G' in text:
        return 7
    if 'H' in text:
        return 7
    if 'M' in text:
        return 7
    if 'O' in text:
        return 7

def add_filepath(text):
    str = OCU_IMG_ROOT + text
    return str
new_ocu_df['paths'] = new_ocu_df['paths'].apply(lambda x : add_filepath(x))
new_ocu_df['disease'] = new_ocu_df['disease'].apply(lambda x : change_label(x))
new_ocu_df['disease'] = new_ocu_df['disease'].astype(int)

# %%
new_ocu_df
# Out:
#                                                paths  disease
# 0       /content/ODIR-5K/Training Images/0_right.jpg        0
# 1       /content/ODIR-5K/Training Images/1_right.jpg        0
# 2       /content/ODIR-5K/Training Images/2_right.jpg        7
# 3       /content/ODIR-5K/Training Images/4_right.jpg        7
# 4       /content/ODIR-5K/Training Images/5_right.jpg        7
# ...                                              ...      ...
# 6387  /content/ODIR-5K/Training Images/4686_left.jpg        7
# 6388  /content/ODIR-5K/Training Images/4688_left.jpg        7
# 6389  /content/ODIR-5K/Training Images/4689_left.jpg        7
# 6390  /content/ODIR-5K/Training Images/4690_left.jpg        7
# 6391  /content/ODIR-5K/Training Images/4784_left.jpg        7
#
# [6392 rows x 2 columns]

# %%
print('Number of normal(0) and cataract(1) and A(2) and G(4) images')
print(new_ocu_df['disease'].value_counts())
# Out:
# Number of normal(0) and cataract(1) and A(2) and G(4) images
# 7    2960
# 0    2873
# 1     293
# 2     266
# Name: disease, dtype: int64

# %% [markdown]
# down sample

# %%
def downsample(df):
    df = pd.concat([
        df.query('disease==1'),
        df.query('disease==2'),
        # df.query('disease==4'),
        df.query('disease==0').sample(300,random_state=SEED)
        # df.query('disease==3').sample(300,random_state=SEED)
    ])
    return df

new_ocu_df = downsample(new_ocu_df)

print('Number of normal(0) and cataract(1) and other_disease(3) and AMD(4) and G(5) images')
print(new_ocu_df['disease'].value_counts())
# Out:
# Number of normal(0) and cataract(1) and other_disease(3) and AMD(4) and G(5) images
# 0    300
# 1    293
# 2    266
# Name: disease, dtype: int64

# %% [markdown]
# ## Create datasets

# %%
df = pd.concat([cat_df, new_ocu_df], ignore_index=True)
# df = cat_df
df
print(df['disease'].value_counts())
# Out:
# 0    600
# 1    393
# 2    266
# 3    100
# Name: disease, dtype: int64

# %%
#for transfer learning test
df1, df2 = train_test_split(df, 
                        test_size=0.5, 
                        random_state=SEED, 
                        stratify=df['disease'])
print(df1['disease'].value_counts())
print(df2['disease'].value_counts())
# Out:
# 0    300
# 1    196
# 2    133
# 3     50
# Name: disease, dtype: int64
# 0    300
# 1    197
# 2    133
# 3     50
# Name: disease, dtype: int64

# %%
df
# Out:
#                                                 paths  disease
# 0        /content/dataset/2_cataract/cataract_027.png        1
# 1        /content/dataset/2_cataract/cataract_053.png        1
# 2        /content/dataset/2_cataract/cataract_023.png        1
# 3        /content/dataset/2_cataract/cataract_030.png        1
# 4        /content/dataset/2_cataract/cataract_098.png        1
# ...                                               ...      ...
# 1354   /content/ODIR-5K/Training Images/3030_left.jpg        0
# 1355  /content/ODIR-5K/Training Images/3169_right.jpg        0
# 1356   /content/ODIR-5K/Training Images/125_right.jpg        0
# 1357   /content/ODIR-5K/Training Images/2487_left.jpg        0
# 1358   /content/ODIR-5K/Training Images/3417_left.jpg        0
#
# [1359 rows x 2 columns]

# %%
train_df_1, test_df_1 = train_test_split(df, 
                                     test_size=0.2, 
                                     random_state=SEED, 
                                     stratify=df['disease'])

train_df_1, val_df_1 = train_test_split(train_df_1,
                                    test_size=0.15,
                                    random_state=SEED,
                                    stratify=train_df_1['disease'])

# %%
#for transfer learning first half data
train_df_1_tran, test_df_1_tran = train_test_split(df1, 
                                     test_size=0.2, 
                                     random_state=SEED, 
                                     stratify=df1['disease'])

train_df_1_tran, val_df_1_tran = train_test_split(train_df_1_tran,
                                    test_size=0.15,
                                    random_state=SEED,
                                    stratify=train_df_1_tran['disease'])

# %%
#for transfer learning second half data
train_df_2_tran, test_df_2_tran = train_test_split(df2, 
                                     test_size=0.2, 
                                     random_state=SEED, 
                                     stratify=df2['disease'])

train_df_2_tran, val_df_2_tran = train_test_split(train_df_2_tran,
                                    test_size=0.15,
                                    random_state=SEED,
                                    stratify=train_df_2_tran['disease'])

# %%
print(val_df_2_tran.value_counts())
# Out:
# paths                                             disease
# /content/dataset/3_retina_disease/Retina_096.png  3          1
# /content/ODIR-5K/Training Images/2179_right.jpg   1          1
# /content/ODIR-5K/Training Images/2181_left.jpg    1          1
# /content/ODIR-5K/Training Images/2198_left.jpg    1          1
# /content/ODIR-5K/Training Images/2200_left.jpg    1          1
#                                                             ..
# /content/dataset/1_normal/NL_040.png              0          1
# /content/dataset/1_normal/NL_054.png              0          1
# /content/dataset/1_normal/NL_061.png              0          1
# /content/dataset/1_normal/NL_071.png              0          1
# /content/ODIR-5K/Training Images/102_left.jpg     2          1
# Length: 82, dtype: int64

# %%
test_df_1
# Out:
#                                                  paths  disease
# 704     /content/ODIR-5K/Training Images/2125_left.jpg        1
# 691     /content/ODIR-5K/Training Images/2108_left.jpg        1
# 391               /content/dataset/1_normal/NL_066.png        0
# 150   /content/dataset/3_retina_disease/Retina_048.png        3
# 521    /content/ODIR-5K/Training Images/1454_right.jpg        1
# ...                                                ...      ...
# 136   /content/dataset/3_retina_disease/Retina_038.png        3
# 1218    /content/ODIR-5K/Training Images/3171_left.jpg        0
# 1057    /content/ODIR-5K/Training Images/2053_left.jpg        2
# 473               /content/dataset/1_normal/NL_137.png        0
# 145   /content/dataset/3_retina_disease/Retina_082.png        3
#
# [272 rows x 2 columns]

# %% [markdown]
# ## image size

# %%
# #1 size
# IMG_HEIGHT = 192
# IMG_WIDTH = 256
# #2 size
# IMG_HEIGHT = 288
# IMG_WIDTH = 384
# 3 size
IMG_HEIGHT = 224
IMG_WIDTH = 224

# %%
def create_datasets(df, img_width, img_height):
    imgs = []
    for path in tqdm(df['paths']):
        img = cv2.imread(path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        # change the img to square
        height = img.shape[0]
        width = img.shape[1]
        img = img[0:height,int((width-height)/2):int((width-(width-height)/2))]
        #
        img = cv2.resize(img, (img_width, img_height))
        imgs.append(img)
        
    imgs = np.array(imgs, dtype='float32')
    df = pd.get_dummies(df['disease'])
    return imgs, df

#whole datasets
train_imgs, train_df = create_datasets(train_df_1, IMG_WIDTH, IMG_HEIGHT)
val_imgs, val_df = create_datasets(val_df_1, IMG_WIDTH, IMG_HEIGHT)
test_imgs, test_df = create_datasets(test_df_1, IMG_WIDTH, IMG_HEIGHT)

#first datasets
train_imgs_1_tran, train_df_1_tran = create_datasets(train_df_1_tran, IMG_WIDTH, IMG_HEIGHT)
val_imgs_1_tran, val_df_1_tran = create_datasets(val_df_1_tran, IMG_WIDTH, IMG_HEIGHT)
test_imgs_1_tran, test_df_1_tran = create_datasets(test_df_1_tran, IMG_WIDTH, IMG_HEIGHT)
#second datasets
train_imgs_2_tran, train_df_2_tran = create_datasets(train_df_2_tran, IMG_WIDTH, IMG_HEIGHT)
val_imgs_2_tran, val_df_2_tran = create_datasets(val_df_2_tran, IMG_WIDTH, IMG_HEIGHT)
test_imgs_2_tran, test_df_2_tran = create_datasets(test_df_2_tran, IMG_WIDTH, IMG_HEIGHT)
# Out:
# 100%|██████████| 923/923 [00:52<00:00, 17.42it/s]
# 100%|██████████| 164/164 [00:09<00:00, 16.46it/s]
# 100%|██████████| 272/272 [00:15<00:00, 17.52it/s]
# 100%|██████████| 461/461 [00:26<00:00, 17.69it/s]
# 100%|██████████| 82/82 [00:04<00:00, 17.38it/s]
# 100%|██████████| 136/136 [00:07<00:00, 17.62it/s]
# 100%|██████████| 462/462 [00:26<00:00, 17.76it/s]
# 100%|██████████| 82/82 [00:04<00:00, 17.26it/s]
# 100%|██████████| 136/136 [00:07<00:00, 17.49it/s]

# %%
train_imgs = train_imgs / 255.0
val_imgs = val_imgs / 255.0
test_imgs = test_imgs / 255.0

train_imgs_1_tran = train_imgs_1_tran / 255.0
val_imgs_1_tran = val_imgs_1_tran / 255.0
test_imgs_1_tran = test_imgs_1_tran / 255.0

train_imgs_2_tran = train_imgs_2_tran / 255.0
val_imgs_2_tran = val_imgs_2_tran / 255.0
test_imgs_2_tran = test_imgs_2_tran / 255.0

# %% [markdown]
# ## Epochs and batch size

# %%
EPOCHS = 100
BATCH_SIZE = 32

# %% [markdown]
# ## Build the model (Xception)

# %%
# Xception = tf.keras.applications.Xception(input_shape=[IMG_HEIGHT, IMG_WIDTH, 3], weights='imagenet', include_top=False)
# Xception.summary()

# %%
def create_model():
  pretrained_model = tf.keras.applications.Xception(input_shape=[IMG_HEIGHT, IMG_WIDTH, 3], weights='imagenet', include_top=False)
  pretrained_model.trainable = True
#   pretrained_model.trainable = False
  model = tf.keras.Sequential([
    pretrained_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(4, activation='softmax')
  ])
  model.compile(
    optimizer='adam',
    loss = 'categorical_crossentropy',
    metrics=['accuracy']
  )
  return model

# with tpu_strategy.scope(): # creating the model in the TPUStrategy scope means we will train the model on the TPU
model_Xception = create_model()
model_Xception.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 1s 0us/step
# 83697664/83683744 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# xception (Functional)        (None, 7, 7, 2048)        20861480
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 8196
# =================================================================
# Total params: 20,869,676
# Trainable params: 20,815,148
# Non-trainable params: 54,528
# _________________________________________________________________

# %%
generator = ImageDataGenerator(horizontal_flip=True, 
                               height_shift_range=0.1,
                               fill_mode='reflect') 



es_callback = tf.keras.callbacks.EarlyStopping(patience=20, 
                                               verbose=1, 
                                               restore_best_weights=True)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=10, verbose=1)

# %%
history = model_Xception.fit(generator.flow(train_imgs_1_tran, 
                                   train_df_1_tran,
                                   batch_size=BATCH_SIZE), 
                    epochs=EPOCHS,
                    steps_per_epoch=len(train_imgs_1_tran)/BATCH_SIZE,
                    callbacks=[es_callback, reduce_lr],
                    validation_data=(val_imgs_1_tran, val_df_1_tran))


pd.DataFrame(history.history)[['accuracy', 'val_accuracy']].plot()
pd.DataFrame(history.history)[['loss', 'val_loss']].plot()
plt.show()
# Out:
# Epoch 1/100
# 14/14 [==============================] - 29s 556ms/step - loss: 0.9138 - accuracy: 0.6421 - val_loss: 2.5599 - val_accuracy: 0.5732
# Epoch 2/100
# 14/14 [==============================] - 7s 462ms/step - loss: 0.6347 - accuracy: 0.7397 - val_loss: 4.6716 - val_accuracy: 0.5244
# Epoch 3/100
# 14/14 [==============================] - 7s 457ms/step - loss: 0.4840 - accuracy: 0.8134 - val_loss: 2.1167 - val_accuracy: 0.6951
# Epoch 4/100
# 14/14 [==============================] - 7s 476ms/step - loss: 0.3616 - accuracy: 0.8547 - val_loss: 2.0349 - val_accuracy: 0.6829
# Epoch 5/100
# 14/14 [==============================] - 7s 458ms/step - loss: 0.3274 - accuracy: 0.8633 - val_loss: 1.4483 - val_accuracy: 0.6951
# Epoch 6/100
# 14/14 [==============================] - 7s 460ms/step - loss: 0.3567 - accuracy: 0.8698 - val_loss: 1.4520 - val_accuracy: 0.7683
# Epoch 7/100
# 14/14 [==============================] - 7s 460ms/step - loss: 0.2211 - accuracy: 0.9154 - val_loss: 1.7812 - val_accuracy: 0.7805
# Epoch 8/100
# 14/14 [==============================] - 7s 457ms/step - loss: 0.2449 - accuracy: 0.9219 - val_loss: 11.2393 - val_accuracy: 0.5854
# Epoch 9/100
# 14/14 [==============================] - 7s 458ms/step - loss: 0.2498 - accuracy: 0.9132 - val_loss: 5.4391 - val_accuracy: 0.5854
# Epoch 10/100
# 14/14 [==============================] - 7s 457ms/step - loss: 0.2176 - accuracy: 0.9328 - val_loss: 2.4767 - val_accuracy: 0.7317
# Epoch 11/100
# 14/14 [==============================] - 7s 457ms/step - loss: 0.1327 - accuracy: 0.9523 - val_loss: 2.6157 - val_accuracy: 0.6707
# Epoch 12/100
# 14/14 [==============================] - 7s 463ms/step - loss: 0.1372 - accuracy: 0.9479 - val_loss: 1.7701 - val_accuracy: 0.7195
# Epoch 13/100
# 14/14 [==============================] - 7s 458ms/step - loss: 0.1427 - accuracy: 0.9523 - val_loss: 1.9873 - val_accuracy: 0.7317
# Epoch 14/100
# 14/14 [==============================] - 7s 463ms/step - loss: 0.1279 - accuracy: 0.9458 - val_loss: 1.5303 - val_accuracy: 0.7683
# Epoch 15/100
# 14/14 [==============================] - 7s 480ms/step - loss: 0.1497 - accuracy: 0.9371 - val_loss: 3.3787 - val_accuracy: 0.6463
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 16/100
# 14/14 [==============================] - 7s 456ms/step - loss: 0.0909 - accuracy: 0.9610 - val_loss: 2.9214 - val_accuracy: 0.6829
# Epoch 17/100
# 14/14 [==============================] - 7s 461ms/step - loss: 0.0869 - accuracy: 0.9675 - val_loss: 2.3355 - val_accuracy: 0.6951
# Epoch 18/100
# 14/14 [==============================] - 7s 457ms/step - loss: 0.0548 - accuracy: 0.9761 - val_loss: 2.0403 - val_accuracy: 0.7073
# Epoch 19/100
# 14/14 [==============================] - 7s 457ms/step - loss: 0.0345 - accuracy: 0.9892 - val_loss: 1.7917 - val_accuracy: 0.7073
# Epoch 20/100
# 14/14 [==============================] - 7s 458ms/step - loss: 0.0382 - accuracy: 0.9892 - val_loss: 1.5860 - val_accuracy: 0.7073
# Epoch 21/100
# 14/14 [==============================] - 7s 456ms/step - loss: 0.0273 - accuracy: 0.9913 - val_loss: 1.4626 - val_accuracy: 0.7195
# Epoch 22/100
# 14/14 [==============================] - 7s 460ms/step - loss: 0.0275 - accuracy: 0.9913 - val_loss: 1.3737 - val_accuracy: 0.7195
# Epoch 23/100
# 14/14 [==============================] - 7s 451ms/step - loss: 0.0272 - accuracy: 0.9913 - val_loss: 1.2922 - val_accuracy: 0.7439
# Epoch 24/100
# 14/14 [==============================] - 7s 459ms/step - loss: 0.0260 - accuracy: 0.9957 - val_loss: 1.2140 - val_accuracy: 0.7439
# Epoch 25/100
# 14/14 [==============================] - 7s 459ms/step - loss: 0.0330 - accuracy: 0.9870 - val_loss: 1.1799 - val_accuracy: 0.7439
# Epoch 26/100
# 14/14 [==============================] - 7s 460ms/step - loss: 0.0218 - accuracy: 0.9913 - val_loss: 1.1697 - val_accuracy: 0.7439
# Epoch 27/100
# 14/14 [==============================] - 7s 455ms/step - loss: 0.0240 - accuracy: 0.9913 - val_loss: 1.1238 - val_accuracy: 0.7561
# Epoch 28/100
# 14/14 [==============================] - 7s 459ms/step - loss: 0.0298 - accuracy: 0.9870 - val_loss: 1.1016 - val_accuracy: 0.7561
# Epoch 29/100
# 14/14 [==============================] - 7s 458ms/step - loss: 0.0250 - accuracy: 0.9892 - val_loss: 1.1311 - val_accuracy: 0.7561
# Epoch 30/100
# 14/14 [==============================] - 7s 457ms/step - loss: 0.0389 - accuracy: 0.9848 - val_loss: 1.1802 - val_accuracy: 0.7439
# Epoch 31/100
# 14/14 [==============================] - 7s 462ms/step - loss: 0.0234 - accuracy: 0.9892 - val_loss: 1.1753 - val_accuracy: 0.7683
# Epoch 32/100
# 14/14 [==============================] - 7s 461ms/step - loss: 0.0253 - accuracy: 0.9913 - val_loss: 1.1335 - val_accuracy: 0.7683
# Epoch 33/100
# 14/14 [==============================] - 7s 459ms/step - loss: 0.0244 - accuracy: 0.9913 - val_loss: 1.0485 - val_accuracy: 0.7927
# Epoch 34/100
# 14/14 [==============================] - 7s 458ms/step - loss: 0.0453 - accuracy: 0.9826 - val_loss: 1.3001 - val_accuracy: 0.7561
# Epoch 35/100
# 14/14 [==============================] - 7s 458ms/step - loss: 0.0213 - accuracy: 0.9913 - val_loss: 1.3823 - val_accuracy: 0.7439
# Epoch 36/100
# 14/14 [==============================] - 7s 459ms/step - loss: 0.0239 - accuracy: 0.9892 - val_loss: 1.3240 - val_accuracy: 0.7439
# Epoch 37/100
# 14/14 [==============================] - 7s 459ms/step - loss: 0.0254 - accuracy: 0.9892 - val_loss: 1.2346 - val_accuracy: 0.7683
# Epoch 38/100
# 14/14 [==============================] - 7s 460ms/step - loss: 0.0191 - accuracy: 0.9913 - val_loss: 1.2163 - val_accuracy: 0.7561
# Epoch 39/100
# 14/14 [==============================] - 7s 457ms/step - loss: 0.0428 - accuracy: 0.9870 - val_loss: 1.2099 - val_accuracy: 0.7683
# Epoch 40/100
# 14/14 [==============================] - 7s 459ms/step - loss: 0.0203 - accuracy: 0.9913 - val_loss: 1.1827 - val_accuracy: 0.7683
# Epoch 41/100
# 14/14 [==============================] - 7s 466ms/step - loss: 0.0209 - accuracy: 0.9913 - val_loss: 1.1932 - val_accuracy: 0.7561
# Epoch 42/100
# 14/14 [==============================] - 7s 458ms/step - loss: 0.0310 - accuracy: 0.9870 - val_loss: 1.1862 - val_accuracy: 0.7683
# Epoch 43/100
# 14/14 [==============================] - 7s 456ms/step - loss: 0.0203 - accuracy: 0.9913 - val_loss: 1.2011 - val_accuracy: 0.7561
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 44/100
# 14/14 [==============================] - 7s 458ms/step - loss: 0.0210 - accuracy: 0.9892 - val_loss: 1.2086 - val_accuracy: 0.7561
# Epoch 45/100
# 14/14 [==============================] - 7s 458ms/step - loss: 0.0198 - accuracy: 0.9913 - val_loss: 1.2140 - val_accuracy: 0.7561
# Epoch 46/100
# 14/14 [==============================] - 7s 459ms/step - loss: 0.0213 - accuracy: 0.9913 - val_loss: 1.2189 - val_accuracy: 0.7683
# Epoch 47/100
# 14/14 [==============================] - 7s 461ms/step - loss: 0.0419 - accuracy: 0.9826 - val_loss: 1.2070 - val_accuracy: 0.7683
# Epoch 48/100
# 14/14 [==============================] - 7s 457ms/step - loss: 0.0188 - accuracy: 0.9913 - val_loss: 1.1920 - val_accuracy: 0.7683
# Epoch 49/100
# 14/14 [==============================] - 7s 461ms/step - loss: 0.0204 - accuracy: 0.9913 - val_loss: 1.1901 - val_accuracy: 0.7683
# Epoch 50/100
# 14/14 [==============================] - 7s 461ms/step - loss: 0.0213 - accuracy: 0.9892 - val_loss: 1.1938 - val_accuracy: 0.7683
# Epoch 51/100
# 14/14 [==============================] - 7s 463ms/step - loss: 0.0214 - accuracy: 0.9913 - val_loss: 1.2030 - val_accuracy: 0.7683
# Epoch 52/100
# 14/14 [==============================] - 7s 457ms/step - loss: 0.0294 - accuracy: 0.9892 - val_loss: 1.2065 - val_accuracy: 0.7683
# Epoch 53/100
# 14/14 [==============================] - 7s 457ms/step - loss: 0.0199 - accuracy: 0.9913 - val_loss: 1.2099 - val_accuracy: 0.7683
# Restoring model weights from the end of the best epoch.
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 00053: early stopping

# %%
model_Xception.evaluate(test_imgs_1_tran, test_df_1_tran)
# Out:
# 5/5 [==============================] - 1s 103ms/step - loss: 0.9986 - accuracy: 0.7941
# [0.998624324798584, 0.7941176295280457]

# %%
model_Xception.evaluate(test_imgs_2_tran, test_df_2_tran)
# Out:
# 5/5 [==============================] - 0s 66ms/step - loss: 0.5876 - accuracy: 0.8603
# [0.5876027941703796, 0.8602941036224365]

# %% [markdown]
# ## Only run for small datasets

# %%
# only for data new

# %%
def create_model():
  pretrained_model = tf.keras.applications.Xception(input_shape=[IMG_HEIGHT, IMG_WIDTH, 3], weights='imagenet', include_top=False)
  pretrained_model.trainable = True
#   pretrained_model.trainable = False
  model = tf.keras.Sequential([
    pretrained_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(4, activation='softmax')
  ])
  model.compile(
    optimizer='adam',
    loss = 'categorical_crossentropy',
    metrics=['accuracy']
  )
  return model

# with tpu_strategy.scope(): # creating the model in the TPUStrategy scope means we will train the model on the TPU
model_Xception_smallds = create_model()
model_Xception_smallds.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# xception (Functional)        (None, 7, 7, 2048)        20861480
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 8196
# =================================================================
# Total params: 20,869,676
# Trainable params: 20,815,148
# Non-trainable params: 54,528
# _________________________________________________________________

# %%
generator = ImageDataGenerator(horizontal_flip=True, 
                               height_shift_range=0.1,
                               fill_mode='reflect') 



es_callback = tf.keras.callbacks.EarlyStopping(patience=20, 
                                               verbose=1, 
                                               restore_best_weights=True)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=10, verbose=1)

# %%
history = model_Xception_smallds.fit(generator.flow(train_imgs_2_tran, 
                                   train_df_2_tran,
                                   batch_size=BATCH_SIZE), 
                    epochs=EPOCHS,
                    steps_per_epoch=len(train_imgs_2_tran)/BATCH_SIZE,
                    callbacks=[es_callback, reduce_lr],
                    validation_data=(val_imgs_2_tran, val_df_2_tran))


pd.DataFrame(history.history)[['accuracy', 'val_accuracy']].plot()
pd.DataFrame(history.history)[['loss', 'val_loss']].plot()
plt.show()
# Out:
# Epoch 1/100
# 14/14 [==============================] - 11s 537ms/step - loss: 0.9964 - accuracy: 0.6169 - val_loss: 1.6859 - val_accuracy: 0.6707
# Epoch 2/100
# 14/14 [==============================] - 7s 456ms/step - loss: 0.7611 - accuracy: 0.7554 - val_loss: 3.7086 - val_accuracy: 0.5976
# Epoch 3/100
# 14/14 [==============================] - 7s 455ms/step - loss: 0.6139 - accuracy: 0.7749 - val_loss: 1.9436 - val_accuracy: 0.6951
# Epoch 4/100
# 14/14 [==============================] - 7s 459ms/step - loss: 0.4917 - accuracy: 0.8442 - val_loss: 3.5137 - val_accuracy: 0.6341
# Epoch 5/100
# 14/14 [==============================] - 7s 463ms/step - loss: 0.4983 - accuracy: 0.8139 - val_loss: 11.8805 - val_accuracy: 0.5610
# Epoch 6/100
# 14/14 [==============================] - 7s 460ms/step - loss: 0.3235 - accuracy: 0.8831 - val_loss: 2.2831 - val_accuracy: 0.7439
# Epoch 7/100
# 14/14 [==============================] - 7s 478ms/step - loss: 0.2291 - accuracy: 0.9242 - val_loss: 2.4710 - val_accuracy: 0.7561
# Epoch 8/100
# 14/14 [==============================] - 7s 458ms/step - loss: 0.3373 - accuracy: 0.8831 - val_loss: 2.5913 - val_accuracy: 0.5488
# Epoch 9/100
# 14/14 [==============================] - 7s 456ms/step - loss: 0.2605 - accuracy: 0.9069 - val_loss: 5.7982 - val_accuracy: 0.3780
# Epoch 10/100
# 14/14 [==============================] - 7s 459ms/step - loss: 0.2078 - accuracy: 0.9048 - val_loss: 3.4006 - val_accuracy: 0.6707
# Epoch 11/100
# 14/14 [==============================] - 7s 461ms/step - loss: 0.1343 - accuracy: 0.9437 - val_loss: 1.8529 - val_accuracy: 0.7927
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 12/100
# 14/14 [==============================] - 7s 458ms/step - loss: 0.0869 - accuracy: 0.9675 - val_loss: 1.2499 - val_accuracy: 0.8171
# Epoch 13/100
# 14/14 [==============================] - 7s 457ms/step - loss: 0.0879 - accuracy: 0.9719 - val_loss: 1.2697 - val_accuracy: 0.8171
# Epoch 14/100
# 14/14 [==============================] - 7s 457ms/step - loss: 0.0559 - accuracy: 0.9848 - val_loss: 1.1737 - val_accuracy: 0.8171
# Epoch 15/100
# 14/14 [==============================] - 7s 450ms/step - loss: 0.0660 - accuracy: 0.9784 - val_loss: 0.9786 - val_accuracy: 0.8171
# Epoch 16/100
# 14/14 [==============================] - 7s 463ms/step - loss: 0.0489 - accuracy: 0.9870 - val_loss: 0.8894 - val_accuracy: 0.8049
# Epoch 17/100
# 14/14 [==============================] - 7s 458ms/step - loss: 0.0562 - accuracy: 0.9892 - val_loss: 0.8565 - val_accuracy: 0.8049
# Epoch 18/100
# 14/14 [==============================] - 7s 459ms/step - loss: 0.0365 - accuracy: 0.9892 - val_loss: 0.8920 - val_accuracy: 0.8049
# Epoch 19/100
# 14/14 [==============================] - 7s 459ms/step - loss: 0.0248 - accuracy: 0.9935 - val_loss: 0.8617 - val_accuracy: 0.8049
# Epoch 20/100
# 14/14 [==============================] - 7s 456ms/step - loss: 0.0348 - accuracy: 0.9892 - val_loss: 0.8644 - val_accuracy: 0.8049
# Epoch 21/100
# 14/14 [==============================] - 7s 458ms/step - loss: 0.0197 - accuracy: 0.9957 - val_loss: 0.8433 - val_accuracy: 0.8049
# Epoch 22/100
# 14/14 [==============================] - 7s 458ms/step - loss: 0.0207 - accuracy: 0.9957 - val_loss: 0.8306 - val_accuracy: 0.8049
# Epoch 23/100
# 14/14 [==============================] - 7s 457ms/step - loss: 0.0206 - accuracy: 0.9957 - val_loss: 0.8249 - val_accuracy: 0.8049
# Epoch 24/100
# 14/14 [==============================] - 7s 457ms/step - loss: 0.0162 - accuracy: 0.9957 - val_loss: 0.8442 - val_accuracy: 0.7927
# Epoch 25/100
# 14/14 [==============================] - 7s 479ms/step - loss: 0.0201 - accuracy: 0.9957 - val_loss: 0.8118 - val_accuracy: 0.7805
# Epoch 26/100
# 14/14 [==============================] - 7s 458ms/step - loss: 0.0192 - accuracy: 0.9957 - val_loss: 0.7881 - val_accuracy: 0.7927
# Epoch 27/100
# 14/14 [==============================] - 7s 455ms/step - loss: 0.0183 - accuracy: 0.9935 - val_loss: 0.7920 - val_accuracy: 0.8049
# Epoch 28/100
# 14/14 [==============================] - 7s 459ms/step - loss: 0.0190 - accuracy: 0.9957 - val_loss: 0.8338 - val_accuracy: 0.8049
# Epoch 29/100
# 14/14 [==============================] - 7s 458ms/step - loss: 0.0174 - accuracy: 0.9957 - val_loss: 0.8565 - val_accuracy: 0.7927
# Epoch 30/100
# 14/14 [==============================] - 7s 463ms/step - loss: 0.0171 - accuracy: 0.9957 - val_loss: 0.8537 - val_accuracy: 0.8049
# Epoch 31/100
# 14/14 [==============================] - 7s 460ms/step - loss: 0.0170 - accuracy: 0.9957 - val_loss: 0.8433 - val_accuracy: 0.8049
# Epoch 32/100
# 14/14 [==============================] - 7s 457ms/step - loss: 0.0145 - accuracy: 0.9957 - val_loss: 0.8391 - val_accuracy: 0.8049
# Epoch 33/100
# 14/14 [==============================] - 7s 457ms/step - loss: 0.0152 - accuracy: 0.9957 - val_loss: 0.8375 - val_accuracy: 0.8049
# Epoch 34/100
# 14/14 [==============================] - 7s 457ms/step - loss: 0.0147 - accuracy: 0.9957 - val_loss: 0.8470 - val_accuracy: 0.8049
# Epoch 35/100
# 14/14 [==============================] - 7s 451ms/step - loss: 0.0155 - accuracy: 0.9957 - val_loss: 0.8605 - val_accuracy: 0.8049
# Epoch 36/100
# 14/14 [==============================] - 7s 458ms/step - loss: 0.0152 - accuracy: 0.9957 - val_loss: 0.9152 - val_accuracy: 0.8049
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 37/100
# 14/14 [==============================] - 7s 459ms/step - loss: 0.0145 - accuracy: 0.9957 - val_loss: 0.9209 - val_accuracy: 0.8049
# Epoch 38/100
# 14/14 [==============================] - 7s 457ms/step - loss: 0.0145 - accuracy: 0.9957 - val_loss: 0.9273 - val_accuracy: 0.8049
# Epoch 39/100
# 14/14 [==============================] - 7s 475ms/step - loss: 0.0175 - accuracy: 0.9935 - val_loss: 0.9278 - val_accuracy: 0.8049
# Epoch 40/100
# 14/14 [==============================] - 7s 466ms/step - loss: 0.0145 - accuracy: 0.9957 - val_loss: 0.9291 - val_accuracy: 0.7927
# Epoch 41/100
# 14/14 [==============================] - 7s 456ms/step - loss: 0.0156 - accuracy: 0.9957 - val_loss: 0.9293 - val_accuracy: 0.7927
# Epoch 42/100
# 14/14 [==============================] - 7s 459ms/step - loss: 0.0161 - accuracy: 0.9957 - val_loss: 0.9358 - val_accuracy: 0.7927
# Epoch 43/100
# 14/14 [==============================] - 7s 486ms/step - loss: 0.0137 - accuracy: 0.9957 - val_loss: 0.9370 - val_accuracy: 0.7927
# Epoch 44/100
# 14/14 [==============================] - 7s 455ms/step - loss: 0.0210 - accuracy: 0.9913 - val_loss: 0.9291 - val_accuracy: 0.7927
# Epoch 45/100
# 14/14 [==============================] - 7s 477ms/step - loss: 0.0144 - accuracy: 0.9957 - val_loss: 0.9258 - val_accuracy: 0.7927
# Epoch 46/100
# 14/14 [==============================] - 7s 456ms/step - loss: 0.0143 - accuracy: 0.9957 - val_loss: 0.9286 - val_accuracy: 0.7927
# Restoring model weights from the end of the best epoch.
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 00046: early stopping

# %%
model_Xception_smallds.evaluate(test_imgs_1_tran, test_df_1_tran) 
# big datasets accuracy
# Out:
# 5/5 [==============================] - 0s 67ms/step - loss: 0.7854 - accuracy: 0.8235
# [0.7854294776916504, 0.8235294222831726]

# %%
model_Xception_smallds.evaluate(test_imgs_2_tran, test_df_2_tran) 
# small datasets accuracy
# Out:
# 5/5 [==============================] - 0s 67ms/step - loss: 0.6673 - accuracy: 0.8309
# [0.6673104166984558, 0.8308823704719543]

# %% [markdown]
# ## transfer learning test

# %%
model_Xception.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# xception (Functional)        (None, 7, 7, 2048)        20861480
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 8196
# =================================================================
# Total params: 20,869,676
# Trainable params: 20,815,148
# Non-trainable params: 54,528
# _________________________________________________________________

# %%
from tensorflow.keras.models import Model
pretrained_model = Model(inputs = model_Xception.input, outputs = model_Xception.get_layer('global_average_pooling2d').output)
pretrained_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# xception_input (InputLayer)  [(None, 224, 224, 3)]     0
# _________________________________________________________________
# xception (Functional)        (None, 7, 7, 2048)        20861480
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# =================================================================
# Total params: 20,861,480
# Trainable params: 20,806,952
# Non-trainable params: 54,528
# _________________________________________________________________

# %%
from tensorflow.keras.models import Model
def create_model_tran():
  pretrained_model = Model(inputs = model_Xception.input, outputs = model_Xception.get_layer('global_average_pooling2d').output)
  pretrained_model.trainable = True
#   pretrained_model.trainable = False
  model = tf.keras.Sequential([
    pretrained_model,
    tf.keras.layers.Dense(4, activation='softmax')
  ])
  model.compile(
    optimizer='adam',
    loss = 'categorical_crossentropy',
    metrics=['accuracy']
  )
  return model

# with tpu_strategy.scope(): # creating the model in the TPUStrategy scope means we will train the model on the TPU
model_Xception_2 = create_model_tran()
model_Xception_2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_1 (Functional)         (None, 2048)              20861480
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 8196
# =================================================================
# Total params: 20,869,676
# Trainable params: 20,815,148
# Non-trainable params: 54,528
# _________________________________________________________________

# %%
generator = ImageDataGenerator(horizontal_flip=True, 
                               height_shift_range=0.1,
                               fill_mode='reflect') 



es_callback = tf.keras.callbacks.EarlyStopping(patience=20, 
                                               verbose=1, 
                                               restore_best_weights=True)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=10, verbose=1)

# %%
history = model_Xception_2.fit(generator.flow(train_imgs_2_tran, 
                                   train_df_2_tran,
                                   batch_size=BATCH_SIZE), 
                    epochs=EPOCHS,
                    steps_per_epoch=len(train_imgs_2_tran)/BATCH_SIZE,
                    callbacks=[es_callback, reduce_lr],
                    validation_data=(val_imgs_2_tran, val_df_2_tran))


pd.DataFrame(history.history)[['accuracy', 'val_accuracy']].plot()
pd.DataFrame(history.history)[['loss', 'val_loss']].plot()
plt.show()
# Out:
# Epoch 1/100
# 14/14 [==============================] - 11s 508ms/step - loss: 0.7644 - accuracy: 0.7229 - val_loss: 0.9415 - val_accuracy: 0.7561
# Epoch 2/100
# 14/14 [==============================] - 7s 455ms/step - loss: 0.4759 - accuracy: 0.8333 - val_loss: 2.6190 - val_accuracy: 0.6585
# Epoch 3/100
# 14/14 [==============================] - 7s 456ms/step - loss: 0.4877 - accuracy: 0.8333 - val_loss: 1.2962 - val_accuracy: 0.7317
# Epoch 4/100
# 14/14 [==============================] - 7s 473ms/step - loss: 0.3575 - accuracy: 0.8939 - val_loss: 3.4283 - val_accuracy: 0.5610
# Epoch 5/100
# 14/14 [==============================] - 7s 457ms/step - loss: 0.2709 - accuracy: 0.9091 - val_loss: 5.2540 - val_accuracy: 0.5610
# Epoch 6/100
# 14/14 [==============================] - 7s 456ms/step - loss: 0.1939 - accuracy: 0.9372 - val_loss: 5.8391 - val_accuracy: 0.4268
# Epoch 7/100
# 14/14 [==============================] - 7s 462ms/step - loss: 0.2137 - accuracy: 0.9221 - val_loss: 0.9683 - val_accuracy: 0.8049
# Epoch 8/100
# 14/14 [==============================] - 7s 458ms/step - loss: 0.2436 - accuracy: 0.9307 - val_loss: 2.9003 - val_accuracy: 0.6341
# Epoch 9/100
# 14/14 [==============================] - 7s 454ms/step - loss: 0.1211 - accuracy: 0.9697 - val_loss: 1.0648 - val_accuracy: 0.8171
# Epoch 10/100
# 14/14 [==============================] - 7s 457ms/step - loss: 0.0741 - accuracy: 0.9762 - val_loss: 5.4009 - val_accuracy: 0.4878
# Epoch 11/100
# 14/14 [==============================] - 7s 456ms/step - loss: 0.1061 - accuracy: 0.9654 - val_loss: 2.3945 - val_accuracy: 0.5732
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 12/100
# 14/14 [==============================] - 7s 458ms/step - loss: 0.0621 - accuracy: 0.9740 - val_loss: 1.6578 - val_accuracy: 0.5976
# Epoch 13/100
# 14/14 [==============================] - 7s 457ms/step - loss: 0.0394 - accuracy: 0.9870 - val_loss: 1.3087 - val_accuracy: 0.6951
# Epoch 14/100
# 14/14 [==============================] - 7s 456ms/step - loss: 0.0397 - accuracy: 0.9870 - val_loss: 1.1162 - val_accuracy: 0.7317
# Epoch 15/100
# 14/14 [==============================] - 7s 449ms/step - loss: 0.0372 - accuracy: 0.9935 - val_loss: 0.9829 - val_accuracy: 0.7439
# Epoch 16/100
# 14/14 [==============================] - 7s 454ms/step - loss: 0.0238 - accuracy: 0.9935 - val_loss: 0.8521 - val_accuracy: 0.7927
# Epoch 17/100
# 14/14 [==============================] - 7s 464ms/step - loss: 0.0309 - accuracy: 0.9913 - val_loss: 0.8223 - val_accuracy: 0.7805
# Epoch 18/100
# 14/14 [==============================] - 7s 458ms/step - loss: 0.0244 - accuracy: 0.9913 - val_loss: 0.8421 - val_accuracy: 0.7805
# Epoch 19/100
# 14/14 [==============================] - 7s 461ms/step - loss: 0.0343 - accuracy: 0.9935 - val_loss: 0.8143 - val_accuracy: 0.7927
# Epoch 20/100
# 14/14 [==============================] - 7s 457ms/step - loss: 0.0223 - accuracy: 0.9935 - val_loss: 0.8117 - val_accuracy: 0.8049
# Epoch 21/100
# 14/14 [==============================] - 7s 455ms/step - loss: 0.0290 - accuracy: 0.9892 - val_loss: 0.8472 - val_accuracy: 0.8171
# Epoch 22/100
# 14/14 [==============================] - 7s 456ms/step - loss: 0.0220 - accuracy: 0.9935 - val_loss: 0.8573 - val_accuracy: 0.8049
# Epoch 23/100
# 14/14 [==============================] - 7s 455ms/step - loss: 0.0191 - accuracy: 0.9957 - val_loss: 0.8649 - val_accuracy: 0.8049
# Epoch 24/100
# 14/14 [==============================] - 7s 456ms/step - loss: 0.0193 - accuracy: 0.9957 - val_loss: 0.8766 - val_accuracy: 0.8049
# Epoch 25/100
# 14/14 [==============================] - 7s 454ms/step - loss: 0.0182 - accuracy: 0.9957 - val_loss: 0.8757 - val_accuracy: 0.8049
# Epoch 26/100
# 14/14 [==============================] - 7s 457ms/step - loss: 0.0188 - accuracy: 0.9935 - val_loss: 0.8729 - val_accuracy: 0.8049
# Epoch 27/100
# 14/14 [==============================] - 7s 458ms/step - loss: 0.0152 - accuracy: 0.9957 - val_loss: 0.8533 - val_accuracy: 0.8049
# Epoch 28/100
# 14/14 [==============================] - 7s 456ms/step - loss: 0.0211 - accuracy: 0.9935 - val_loss: 0.8180 - val_accuracy: 0.8171
# Epoch 29/100
# 14/14 [==============================] - 7s 461ms/step - loss: 0.0192 - accuracy: 0.9935 - val_loss: 0.8191 - val_accuracy: 0.8049
# Epoch 30/100
# 14/14 [==============================] - 7s 458ms/step - loss: 0.0162 - accuracy: 0.9957 - val_loss: 0.8346 - val_accuracy: 0.8049
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 31/100
# 14/14 [==============================] - 7s 459ms/step - loss: 0.0172 - accuracy: 0.9935 - val_loss: 0.8333 - val_accuracy: 0.8049
# Epoch 32/100
# 14/14 [==============================] - 7s 459ms/step - loss: 0.0162 - accuracy: 0.9957 - val_loss: 0.8336 - val_accuracy: 0.8049
# Epoch 33/100
# 14/14 [==============================] - 7s 456ms/step - loss: 0.0192 - accuracy: 0.9935 - val_loss: 0.8297 - val_accuracy: 0.8049
# Epoch 34/100
# 14/14 [==============================] - 7s 454ms/step - loss: 0.0201 - accuracy: 0.9935 - val_loss: 0.8252 - val_accuracy: 0.8049
# Epoch 35/100
# 14/14 [==============================] - 7s 457ms/step - loss: 0.0178 - accuracy: 0.9957 - val_loss: 0.8239 - val_accuracy: 0.8049
# Epoch 36/100
# 14/14 [==============================] - 7s 461ms/step - loss: 0.0177 - accuracy: 0.9935 - val_loss: 0.8291 - val_accuracy: 0.8049
# Epoch 37/100
# 14/14 [==============================] - 7s 456ms/step - loss: 0.0157 - accuracy: 0.9957 - val_loss: 0.8322 - val_accuracy: 0.8049
# Epoch 38/100
# 14/14 [==============================] - 7s 448ms/step - loss: 0.0183 - accuracy: 0.9935 - val_loss: 0.8321 - val_accuracy: 0.8049
# Epoch 39/100
# 14/14 [==============================] - 7s 457ms/step - loss: 0.0245 - accuracy: 0.9935 - val_loss: 0.8424 - val_accuracy: 0.8049
# Epoch 40/100
# 14/14 [==============================] - 7s 474ms/step - loss: 0.0138 - accuracy: 0.9957 - val_loss: 0.8430 - val_accuracy: 0.8171
# Restoring model weights from the end of the best epoch.
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 00040: early stopping

# %%
model_Xception_2.evaluate(test_imgs_1_tran, test_df_1_tran)
# Out:
# 5/5 [==============================] - 0s 65ms/step - loss: 0.8573 - accuracy: 0.8235
# [0.8572573661804199, 0.8235294222831726]

# %%
model_Xception_2.evaluate(test_imgs_2_tran, test_df_2_tran)
# Out:
# 5/5 [==============================] - 0s 65ms/step - loss: 0.7761 - accuracy: 0.8382
# [0.7761387825012207, 0.8382353186607361]

# %% [markdown]
# ## Save the model

# %%
model_Xception.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# xception (Functional)        (None, 7, 7, 2048)        20861480
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 8196
# =================================================================
# Total params: 20,869,676
# Trainable params: 20,815,148
# Non-trainable params: 54,528
# _________________________________________________________________

# %% [markdown]
# ## Build the model (EfficientNetB0)

# %%
# !pip install -q efficientnet >> /dev/null
import efficientnet.tfkeras as efn

def build_model(img_height, img_width, n):
    inp = Input(shape=(img_height,img_width,n))
    efnet = efn.EfficientNetB0(
        input_shape=(img_height,img_width,n), 
        weights='imagenet', 
        include_top=False
    )
    x = efnet(inp)
    x = GlobalAveragePooling2D()(x)
    x = Dense(4, activation='softmax')(x)
    model = tf.keras.Model(inputs=inp, outputs=x)
    opt = tf.keras.optimizers.Adam(learning_rate=0.000003)
    loss = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.01)
    model.compile(optimizer=opt, loss=loss, metrics=['accuracy'])
    return model

model_Efficient = build_model(IMG_HEIGHT, IMG_WIDTH, 3)
model_Efficient.summary()
# Out:
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b0_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 16809984/16804768 [==============================] - 1s 0us/step
# 16818176/16804768 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# efficientnet-b0 (Functional) (None, 7, 7, 1280)        4049564
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1280)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 5124
# =================================================================
# Total params: 4,054,688
# Trainable params: 4,012,672
# Non-trainable params: 42,016
# _________________________________________________________________

# %%
generator = ImageDataGenerator(horizontal_flip=True, 
                               height_shift_range=0.1,
                               fill_mode='reflect') 



es_callback = tf.keras.callbacks.EarlyStopping(patience=20, 
                                               verbose=1, 
                                               restore_best_weights=True)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=10, verbose=1)

# %%
history = model_Efficient.fit(generator.flow(train_imgs, 
                                   train_df,
                                   batch_size=BATCH_SIZE), 
                    epochs=1000,
                    steps_per_epoch=len(train_imgs)/BATCH_SIZE,
                    callbacks=[es_callback, reduce_lr],
                    validation_data=(val_imgs, val_df))


pd.DataFrame(history.history)[['accuracy', 'val_accuracy']].plot()
pd.DataFrame(history.history)[['loss', 'val_loss']].plot()
plt.show()
# Out:
# Epoch 1/1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-f476c8a7f4fd> in <module>()
#       5                     steps_per_epoch=len(train_imgs)/BATCH_SIZE,
#       6                     callbacks=[es_callback, reduce_lr],
# ----> 7                     validation_data=(val_imgs, val_df))
#       8
#       9
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# -> 1184               tmp_logs = self.train_function(iterator)
#    1185               if data_handler.should_sync:
#    1186                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     948         # Lifting succeeded, so variables are initialized and we can run the
#     949         # stateless function.
# --> 950         return self._stateless_fn(*args, **kwds)
#     951     else:
#     952       _, _, _, filtered_flat_args = \
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3036     with self._lock:
#    3037       (graph_function,
# -> 3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3039     return graph_function._call_flat(
#    3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3461
#    3462           self._function_cache.missed.add(call_context_key)
# -> 3463           graph_function = self._create_graph_function(args, kwargs)
#    3464           self._function_cache.primary[cache_key] = graph_function
#    3465
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3306             arg_names=arg_names,
#    3307             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3308             capture_by_value=self._capture_by_value),
#    3309         self._function_attributes,
#    3310         function_spec=self.function_spec,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1005         _, original_func = tf_decorator.unwrap(python_func)
#    1006
# -> 1007       func_outputs = python_func(*func_args, **func_kwargs)
#    1008
#    1009       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     666         # the function a weak reference to itself to avoid a reference cycle.
#     667         with OptionalXlaContext(compile_with_xla):
# --> 668           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     669         return out
#     670
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     988                     recursive=True,
#     989                     optional_features=autograph_options,
# --> 990                     user_requested=True,
#     991                 ))
#     992           except Exception as e:  # pylint:disable=broad-except
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     442     try:
#     443       if kwargs is not None:
# --> 444         result = converted_f(*effective_args, **kwargs)
#     445       else:
#     446         result = converted_f(*effective_args)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     334   if conversion.is_in_allowlist_cache(f, options):
#     335     logging.log(2, 'Allowlisted %s: from cache', f)
# --> 336     return _call_unconverted(f, args, kwargs, options, False)
#     337
#     338   if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     462   if kwargs is not None:
#     463     return f(*args, **kwargs)
# --> 464   return f(*args)
#     465
#     466
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in step_function(model, iterator)
#     840
#     841       data = next(iterator)
# --> 842       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     843       outputs = reduce_per_replica(
#     844           outputs, self.distribute_strategy, reduction='first')
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py in run(***failed resolving arguments***)
#    1284       fn = autograph.tf_convert(
#    1285           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1286       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#    1287
#    1288   def reduce(self, reduce_op, value, axis):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py in call_for_each_replica(self, fn, args, kwargs)
#    2847       kwargs = {}
#    2848     with self._container_strategy().scope():
# -> 2849       return self._call_for_each_replica(fn, args, kwargs)
#    2850
#    2851   def _call_for_each_replica(self, fn, args, kwargs):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py in _call_for_each_replica(self, fn, args, kwargs)
#    3630   def _call_for_each_replica(self, fn, args, kwargs):
#    3631     with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3632       return fn(*args, **kwargs)
#    3633
#    3634   def _reduce_to(self, reduce_op, value, destinations, options):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     690       try:
#     691         with conversion_ctx:
# --> 692           return converted_call(f, args, kwargs, options=options)
#     693       except Exception as e:  # pylint:disable=broad-except
#     694         if hasattr(e, 'ag_error_metadata'):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     380
#     381   if not options.user_requested and conversion.is_allowlisted(f):
# --> 382     return _call_unconverted(f, args, kwargs, options)
#     383
#     384   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     461
#     462   if kwargs is not None:
# --> 463     return f(*args, **kwargs)
#     464   return f(*args)
#     465
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in run_step(data)
#     833
#     834       def run_step(data):
# --> 835         outputs = model.train_step(data)
#     836         # Ensure counter is updated only if `train_step` succeeds.
#     837         with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in train_step(self, data)
#     789           y, y_pred, sample_weight, regularization_losses=self.losses)
#     790     # Run backwards pass.
# --> 791     self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     792     self.compiled_metrics.update_state(y, y_pred, sample_weight)
#     793     # Collect metrics to return
#
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py in minimize(self, loss, var_list, grad_loss, name, tape)
#     519     """
#     520     grads_and_vars = self._compute_gradients(
# --> 521         loss, var_list=var_list, grad_loss=grad_loss, tape=tape)
#     522     return self.apply_gradients(grads_and_vars, name=name)
#     523
#
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py in _compute_gradients(self, loss, var_list, grad_loss, tape)
#     570     var_list = tf.nest.flatten(var_list)
#     571     with tf.name_scope(self._name + "/gradients"):
# --> 572       grads_and_vars = self._get_gradients(tape, loss, var_list, grad_loss)
#     573
#     574     self._assert_valid_dtypes([
#
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py in _get_gradients(self, tape, loss, var_list, grad_loss)
#     452   def _get_gradients(self, tape, loss, var_list, grad_loss=None):
#     453     """Called in `minimize` to compute gradients from loss."""
# --> 454     grads = tape.gradient(loss, var_list, grad_loss)
#     455     return list(zip(grads, var_list))
#     456
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/backprop.py in gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1088         output_gradients=output_gradients,
#    1089         sources_raw=flat_sources_raw,
# -> 1090         unconnected_gradients=unconnected_gradients)
#    1091
#    1092     if not self._persistent:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/imperative_grad.py in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      75       output_gradients,
#      76       sources_raw,
# ---> 77       compat.as_str(unconnected_gradients.value))
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/backprop.py in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     157       gradient_name_scope += forward_pass_name_scope + "/"
#     158     with ops.name_scope(gradient_name_scope):
# --> 159       return grad_fn(mock_op, *out_grads)
#     160   else:
#     161     return grad_fn(mock_op, *out_grads)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/math_grad.py in _MulGrad(op, grad)
#    1375
#    1376   (sx, rx, must_reduce_x), (sy, ry, must_reduce_y) = (
# -> 1377       SmartBroadcastGradientArgs(x, y, grad))
#    1378   x = math_ops.conj(x)
#    1379   y = math_ops.conj(y)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/math_grad.py in SmartBroadcastGradientArgs(x, y, grad)
#     106   if (x_shape_tuple is None or None in x_shape_tuple or
#     107       y_shape_tuple is None or None in y_shape_tuple):
# --> 108     sx = array_ops.shape_internal(x, optimize=False)
#     109     sy = array_ops.shape_internal(y, optimize=False)
#     110     rx, ry = gen_array_ops.broadcast_gradient_args(sx, sy)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py in shape_internal(input, name, optimize, out_type)
#     677         if optimize and input_shape.is_fully_defined():
#     678           return constant(input_shape.as_list(), out_type, name=name)
# --> 679       return gen_array_ops.shape(input, name=name, out_type=out_type)
#     680
#     681
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_array_ops.py in shape(input, out_type, name)
#    9198   out_type = _execute.make_type(out_type, "out_type")
#    9199   _, _, _op, _outputs = _op_def_library._apply_op_helper(
# -> 9200         "Shape", input=input, out_type=out_type, name=name)
#    9201   _result = _outputs[:]
#    9202   if _execute.must_record_gradient():
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     663         input_types.extend(types)
#     664       else:
# --> 665         input_types.extend(base_types)
#     666
#     667     # Process remaining attrs
#
# KeyboardInterrupt:

# %%
model_Efficient.evaluate(test_imgs, test_df)

# %%
predictions = model_Efficient.predict(test_imgs, steps=len(test_df), verbose=1)
y_pred = np.argmax(predictions, axis=1)

y_true = test_df_1['disease'].tolist()

from sklearn.metrics import classification_report, f1_score

f1_score(y_true, y_pred, average='weighted')

# %%
#300 B3 83.5
#400 B0 72.8
#400 B0 4 class 48 batch size -- 80.8 acc 
#400 B0 4 class 8 batch size -- 0.845588207244873 acc 0.6309579109532658 f1

# %% [markdown]
# ## Build model(resNet50)

# %%
def create_model():
  pretrained_model = tf.keras.applications.ResNet50(input_shape=[IMG_HEIGHT, IMG_WIDTH, 3], include_top=False)
  pretrained_model.trainable = True
  model = tf.keras.Sequential([
    pretrained_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(4, activation='softmax')
  ])
  model.compile(
    optimizer='adam',
    loss = 'categorical_crossentropy',
    metrics=['accuracy']
  )
  return model

# with tpu_strategy.scope(): # creating the model in the TPUStrategy scope means we will train the model on the TPU
model_resnet50 = create_model()
model_resnet50.summary()

# %%
generator = ImageDataGenerator(horizontal_flip=True, 
                               height_shift_range=0.1,
                               fill_mode='reflect') 



es_callback = tf.keras.callbacks.EarlyStopping(patience=20, 
                                               verbose=1, 
                                               restore_best_weights=True)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=10, verbose=1)

# %%
history = model_resnet50.fit(generator.flow(train_imgs, 
                                   train_df,
                                   batch_size=BATCH_SIZE), 
                    epochs=EPOCHS,
                    steps_per_epoch=len(train_imgs)/BATCH_SIZE,
                    callbacks=[es_callback, reduce_lr],
                    validation_data=(val_imgs, val_df))


pd.DataFrame(history.history)[['accuracy', 'val_accuracy']].plot()
pd.DataFrame(history.history)[['loss', 'val_loss']].plot()
plt.show()

# %%
model_resnet50.evaluate(test_imgs, test_df)

# %%
predictions = model_resnet50.predict(test_imgs, steps=len(test_df), verbose=1)
y_pred = np.argmax(predictions, axis=1)

y_true = test_df_1['disease'].tolist()

from sklearn.metrics import classification_report, f1_score

f1_score(y_true, y_pred, average='weighted')
